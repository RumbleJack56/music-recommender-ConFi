# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
SPOTIFY_CLIENT_ID = "e21dcdaab8b54409b8b74f0d46979c9a"
SPOTIFY_CLIENT_SECRET = "197b08345d444e9b81198ac15e8d0532"
sp = spotipy.Spotify(client_credentials_manager=SpotifyClientCredentials(SPOTIFY_CLIENT_ID,SPOTIFY_CLIENT_SECRET))

# %%
data = sp.artist_related_artists('4rBWAKUMmLkl685zvk0LBH')

# %%
data
# Out:
# {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6UJS43T8NPhmWmmpFY0hzP'},
#    'followers': {'href': None, 'total': 101111},
#    'genres': ['persian melodic rap', 'persian sad rap'],
#    'href': 'https://api.spotify.com/v1/artists/6UJS43T8NPhmWmmpFY0hzP',
#    'id': '6UJS43T8NPhmWmmpFY0hzP',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab6761610000e5eb6bdacfa57398a3b354f708de',
#      'width': 640},
#     {'height': 320,
#      'url': 'https://i.scdn.co/image/ab676161000051746bdacfa57398a3b354f708de',
#      'width': 320},
#     {'height': 160,
#      'url': 'https://i.scdn.co/image/ab6761610000f1786bdacfa57398a3b354f708de',
#      'width': 160}],
#    'name': 'Hoomaan',
#    'popularity': 46,
#    'type': 'artist',
#    'uri': 'spotify:artist:6UJS43T8NPhmWmmpFY0hzP'},
#   {'external_urls': {'spotify': 'https://open.spotify.com/artist/4mST4sikQtpiH5dIkRxaCT'},
#    'followers': {'href': None, 'total': 75755},
# ...

# %%
import json 
from functools import reduce
with open('selected_users.json','r',encoding='utf-8') as f: jsondata = json.loads(f.read())
# print(json.dumps(jsondata,indent=4))


len(set(reduce(lambda x,y : x+y , [k['SongIDs'] for k in jsondata])))
# Out:
# 24999

# %%
import pandas as pd,numpy as np


df = pd.read_pickle('full_df.pkl')
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 4
#       1 import pandas as pd,numpy as np
# ----> 4 df = pd.read_pickle('full_df.pkl')
#       5 df
#
# File c:\Users\ujjwa\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\pickle.py:222, in read_pickle(filepath_or_buffer, compression, storage_options)
#     217             return pickle.load(handles.handle)  # type: ignore[arg-type]
#     218     except excs_to_catch:
#     219         # e.g.
#     220         #  "No module named 'pandas.core.sparse.series'"
#     221         #  "Can't get attribute '__nat_unpickle' on <module 'pandas._libs.tslib"
# --> 222         return pc.load(handles.handle, encoding=None)
#     223 except UnicodeDecodeError:
#     224     # e.g. can occur for files written in py27; see GH#28645 and GH#31988
# ...

# %%
# Out:
# UsageError: Line magic function `%python` not found (But cell magic `%%python` exists, did you mean that instead?).
